# %% [markdown]
# # Projekt
# **Filip Jakovina, 0036535147**
# ## A Machine Learning Strategy For Predicting March Madness Winnerss

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Priprema i vizualizacija podataka

# %% [markdown]
# ## Učitavanje podataka

# %%
rscr = pd.read_csv("data/regular_season_compact_results.csv")
rsdr = pd.read_csv("data/regular_season_detailed_results.csv")
s = pd.read_csv("data/seasons.csv")
t = pd.read_csv("data/teams.csv")
tcr = pd.read_csv("data/tourney_compact_results.csv")
tdr = pd.read_csv("data/tourney_detailed_results.csv")
tse = pd.read_csv("data/tourney_seeds.csv")
tsl = pd.read_csv("data/tourney_slots.csv")

# %% [markdown]
# ## Prikaz i analiza podataka

# %% [markdown]
# ### Sezone
# Popis sezona

# %%
with pd.option_context("display.max_rows", None, 'display.max_columns', None):
    display(s)
# Out:
#     season     dayzero      regionW    regionX         regionY       regionZ
# 0     1985  10/29/1984         East       West         Midwest     Southeast
# 1     1986  10/28/1985         East    Midwest       Southeast          West
# 2     1987  10/27/1986         East  Southeast         Midwest          West
# 3     1988  11/02/1987         East    Midwest       Southeast          West
# 4     1989  10/31/1988         East       West         Midwest     Southeast
# 5     1990  10/30/1989         East    Midwest       Southeast          West
# 6     1991  10/29/1990         East  Southeast         Midwest          West
# 7     1992  11/04/1991         East       West         Midwest     Southeast
# 8     1993  11/02/1992         East    Midwest       Southeast          West
# 9     1994  11/01/1993         East  Southeast         Midwest          West
# 10    1995  10/31/1994         East       West         Midwest     Southeast
# ...

# %% [markdown]
# Pojašnjenja značajki:
# - Season &ndash; jedno-znakovni identifikator sezone
# - Years &ndash; godine kroz koje se proteže sezona
# - Dayzero &ndash; datum početka sezone
# - RegionW/X/Y/Z &ndash; 4 regije u završnom turniru sezone

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   season   31 non-null     int64
#  1   dayzero  31 non-null     object
#  2   regionW  31 non-null     object
#  3   regionX  31 non-null     object
#  4   regionY  31 non-null     object
#  5   regionZ  31 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.6+ KB

# %%
s.describe(include='all')
# Out:
#              season     dayzero regionW  regionX  regionY regionZ
# count     31.000000          31      31       31       31      31
# unique          NaN          31       3        7        6       7
# top             NaN  10/29/1984    East  Midwest  Midwest    West
# freq            NaN           1      28        9       18      21
# mean    2000.000000         NaN     NaN      NaN      NaN     NaN
# std        9.092121         NaN     NaN      NaN      NaN     NaN
# min     1985.000000         NaN     NaN      NaN      NaN     NaN
# 25%     1992.500000         NaN     NaN      NaN      NaN     NaN
# 50%     2000.000000         NaN     NaN      NaN      NaN     NaN
# 75%     2007.500000         NaN     NaN      NaN      NaN     NaN
# max     2015.000000         NaN     NaN      NaN      NaN     NaN

# %% [markdown]
# Ova tablica ne sadrži nedostajuće i stršeće podatke. <br>
# Sljedeće ćemo vidjeti koje regije se koliko puta pojavljuju:

# %%
columns = ['regionW', 'regionX', 'regionY', 'regionZ']
region_counts = {}

for column in columns:
    counts = s[column].value_counts().to_dict()
    for region, count in counts.items():
        region_counts[region] = region_counts.get(region, 0) + count

region_counts = sorted(region_counts.items(), key=lambda item: item[1], reverse=True)
for region, count in region_counts:
    print(f"{region}: {count}")
# Out:
# East: 28
# West: 28
# Midwest: 27
# South: 14
# Southeast: 14
# Atlanta: 2
# Albuquerque: 1
# Phoenix: 1
# Chicago: 1
# Oakland: 1
# EastRutherford: 1
# Austin: 1
# Minneapolis: 1
# StLouis: 1
# Syracuse: 1
# WashingtonDC: 1
# Southwest: 1

# %% [markdown]
# Iz sljedećeg prikaza možemo razlikovati dvije vrste regija: Geografski određene regije(East, West, Midwest, South, Southeast, Southwest)
# koje se pojavljuju više puta <br>te regije koje su gradovi(Atlanta, Albuquerque, Phoenix, Chicago...)<br>
# Imena tih gradova valjalo bi zamijeniti sa geografskom regijom kojoj ti gradovi pripadaju i ponoviti brojanje.

# %%
replacements = {
    'Atlanta': 'South',
    'Albuquerque': 'West',
    'Phoenix': 'West',
    'Chicago': 'Midwest',
    'Oakland': 'West',
    'EastRutherford': 'East',
    'Austin': 'South',
    'Minneapolis': 'West',
    'StLouis': 'Midwest',
    'Syracuse': 'East',
    'WashingtonDC': 'East',
}
for column in columns:
    s[column] = s[column].replace(replacements)

region_counts = {}

for column in columns:
    counts = s[column].value_counts().to_dict()
    for region, count in counts.items():
        region_counts[region] = region_counts.get(region, 0) + count

region_counts = sorted(region_counts.items(), key=lambda item: item[1], reverse=True)
for region, count in region_counts:
    print(f"{region}: {count}")
# Out:
# West: 32
# East: 31
# Midwest: 29
# South: 17
# Southeast: 14
# Southwest: 1

# %% [markdown]
# ### Timovi
# Popis identifikatora i imena timova

# %%
with pd.option_context("display.max_rows", 10, 'display.max_columns', None):
    display(t)
# Out:
#      team_id      team_name
# 0       1101    Abilene Chr
# 1       1102      Air Force
# 2       1103          Akron
# 3       1104        Alabama
# 4       1105    Alabama A&M
# ..       ...            ...
# 359     1460      Wright St
# 360     1461        Wyoming
# 361     1462         Xavier
# 362     1463           Yale
# 363     1464  Youngstown St
#
# [364 rows x 2 columns]

# %%
t.describe(include='all')
# Out:
#             team_id    team_name
# count    364.000000          364
# unique          NaN          364
# top             NaN  Abilene Chr
# freq            NaN            1
# mean    1282.500000          NaN
# std      105.221988          NaN
# min     1101.000000          NaN
# 25%     1191.750000          NaN
# 50%     1282.500000          NaN
# 75%     1373.250000          NaN
# max     1464.000000          NaN

# %% [markdown]
# Kako ova tablica sadrži samo imena timova nije potrebno tražiti nedostajuće i stršeće vrijednosti te raditi vizualizacije

# %% [markdown]
# ### Rezultati regularnog dijela sezone
# Rezultati svake utakmice u regularnom dijelu sezone, uz potpunu statistiku od sezone 2003. do 2014.

# %%
with pd.option_context("display.max_rows", 10, 'display.max_columns', None):
    display(rsdr)
# Out:
#        season  daynum  wteam  wscore  lteam  lscore wloc  numot  wfgm  wfga  \
# 0        2003      10   1104      68   1328      62    N      0    27    58
# 1        2003      10   1272      70   1393      63    N      0    26    62
# 2        2003      11   1266      73   1437      61    N      0    24    58
# 3        2003      11   1296      56   1457      50    N      0    18    38
# 4        2003      11   1400      77   1208      71    N      0    30    61
# ...       ...     ...    ...     ...    ...     ...  ...    ...   ...   ...
# 60513    2014     132   1196      61   1246      60    N      0    23    53
# 60514    2014     132   1277      69   1276      55    N      0    27    54
# 60515    2014     132   1386      65   1433      61    N      0    24    50
# 60516    2014     132   1418      82   1209      81    N      1    32    75
# 60517    2014     132   1438      72   1181      63    N      0    21    47
#
# ...

# %% [markdown]
# Pojašnjenja značajki (W - pobjednik, L - gubitnik):
#  - Season &ndash; identifikator sezone (odgovara stupcu "season" u datoteci "seasons.csv")
#  - Daynum &ndash; broj dana nakon "dayzero" datuma u "seasons.csv"
#  - Wteam/Lteam &ndash; Id momčadi iz "teams.csv"
#  - Wscore/Lscore &ndash; Broj poena
#  - Wloc &ndash; Lokacija pobjedničke momčadi (H - domaćin, A - gost, N - neutralan teren)
#  - Numot &ndash; Broj odigranih produžetaka na utakmici
#  - Wfgm/Lfgm &ndash; Broj pogođenih koševa (2 poena)
#  - Wfga/Lfga &ndash; Broj bacanja prema košu (2 poena)
#  - Wfgm3/Lfgm3 &ndash; Broj pogođenih trica (3 poena)
#  - Wfga3/Lfga3 &ndash; Broj bacanja trica (3 poena)
#  - Wftm/Lftm &ndash; Broj pogođenih slobodnih bacanja (1 poen)
#  - Wfta/Lfta &ndash; Broj slobodnih bacanja (1 poen)
#  - Wor/Lor &ndash; Broj uhvaćenih lopti nakon šuta u napadu
#  - Wdr/Ldr &ndash; Broj uhvaćenih lopti nakon šuta u obrani
#  - Wast/Last &ndash; Broj asistencija
#  - Wto/Lto &ndash; Broj izgubljenih lopti u napadu
#  - Wstl/Lstl &ndash; Broj oduzetih lopti
#  - Wblk/Lblk &ndash; Broj blokiranja protivnika
#  - Wpf/Lpf &ndash; Broj osobnih pogrešaka

# %%
rsdr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60518 entries, 0 to 60517
# Data columns (total 34 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   season  60518 non-null  int64
#  1   daynum  60518 non-null  int64
#  2   wteam   60518 non-null  int64
#  3   wscore  60518 non-null  int64
#  4   lteam   60518 non-null  int64
#  5   lscore  60518 non-null  int64
#  6   wloc    60518 non-null  object
#  7   numot   60518 non-null  int64
#  8   wfgm    60518 non-null  int64
#  9   wfga    60518 non-null  int64
#  10  wfgm3   60518 non-null  int64
#  11  wfga3   60518 non-null  int64
#  12  wftm    60518 non-null  int64
#  13  wfta    60518 non-null  int64
#  14  wor     60518 non-null  int64
#  15  wdr     60518 non-null  int64
#  16  wast    60518 non-null  int64
#  17  wto     60518 non-null  int64
#  18  wstl    60518 non-null  int64
#  19  wblk    60518 non-null  int64
#  20  wpf     60518 non-null  int64
# ...

# %%
rsdr.describe(include='all')
# Out:
#               season        daynum         wteam        wscore         lteam  \
# count   60518.000000  60518.000000  60518.000000  60518.000000  60518.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     2008.683284     71.551737   1286.584851     74.583826   1282.465878
# std         3.425290     35.159429    104.972198     11.054579    104.218602
# min      2003.000000      0.000000   1101.000000     34.000000   1101.000000
# 25%      2006.000000     40.000000   1196.000000     67.000000   1191.000000
# 50%      2009.000000     75.000000   1284.000000     74.000000   1281.000000
# 75%      2012.000000    102.000000   1379.000000     82.000000   1374.000000
# max      2014.000000    132.000000   1464.000000    142.000000   1464.000000
#
# ...

# %% [markdown]
# #### Stršeće vrijednosti

# %% [markdown]
# Kandidat za stršeće vrijednosti bio bi numot.

# %%
tmp = rsdr.sort_values(by='numot')
plt.plot(range(len(tmp.numot)), tmp.numot)
plt.ylabel('numot')
plt.show()

# %% [markdown]
# Prikazat ćemo samo zadnjih 5000 vrijednosti

# %%
plt.plot(range(len(tmp.numot[-5000:])), tmp.numot[-5000:])
plt.ylabel('numot')
plt.show()

# %% [markdown]
# Možemo zaključiti da značajka numot ima stršeće vrijednosti

# %% [markdown]
# #### Nedostajuće vrijednosti

# %%
rsdr.isna().sum()
# Out:
# season    0
# daynum    0
# wteam     0
# wscore    0
# lteam     0
# lscore    0
# wloc      0
# numot     0
# wfgm      0
# wfga      0
# wfgm3     0
# wfga3     0
# wftm      0
# wfta      0
# wor       0
# wdr       0
# wast      0
# wto       0
# wstl      0
# wblk      0
# wpf       0
# lfgm      0
# lfga      0
# lfgm3     0
# lfga3     0
# lftm      0
# lfta      0
# lor       0
# ldr       0
# last      0
# lto       0
# lstl      0
# lblk      0
# lpf       0
# dtype: int64

# %% [markdown]
# Možemo vidjeti da ova tablica nema nedostajuće vrijednosti

# %% [markdown]
# #### Vizualizacija

# %% [markdown]
# Prvo ćemo prikazati broj pobjeda i poraza svake momčadi ikada

# %%
games_won = rsdr['wteam'].value_counts().reset_index()
games_won.columns = ['Team_ID', 'Games_Won']

games_lost = rsdr['lteam'].value_counts().reset_index()
games_lost.columns = ['Team_ID', 'Games_Lost']

team_stats = pd.merge(games_won, games_lost, on='Team_ID', how='outer').fillna(0)

teams = team_stats['Team_ID']
games_won = team_stats['Games_Won']
games_lost = team_stats['Games_Lost']


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
ax1.bar(teams, games_won, color='green', label='won')
ax1.legend(loc='best')
ax1.set_xlabel('Team Id')
ax1.set_ylabel('Number of games')
ax1.grid()
ax2.bar(teams, games_lost, color='red', label='lost')
ax2.legend(loc='best')
ax2.set_xlabel('Team Id')
ax2.grid()
plt.show()

# %% [markdown]
# Želimo također vidjeti postotak pobjeda svake momčadi <br>
# Tako da ćemo prvo prikazati postotak za svaku momčad i onda ćemo prikazati poredane postotke

# %%
team_stats['Percentage_Won'] = (team_stats['Games_Won'] / (team_stats['Games_Won'] + team_stats['Games_Lost'])) * 100
percentage_won = team_stats['Percentage_Won']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
ax1.bar(teams, percentage_won, label='% Won')
ax1.legend(loc='best')
ax1.set_xlabel('Team Id')
ax1.set_ylabel('Percentage')
ax1.grid()

team_stats = team_stats.sort_values(by='Percentage_Won', ascending=False)
index = range(len(percentage_won))
ax2.bar(index, percentage_won, label='% Won')
ax2.legend(loc='best')
ax2.grid()

plt.show()

# %% [markdown]
# ##### Sada ćemo prikazati statistike pobjednika i gubitnika te pokazati korelacije podataka

# %% [markdown]
# ##### Pobjednici

# %%
plt.boxplot((rsdr.wscore, rsdr.wfgm, rsdr.wfgm3, rsdr.wftm, rsdr.wor, rsdr.wdr, rsdr.wast, rsdr.wto, rsdr.wstl, rsdr.wblk, rsdr.wpf), 
            labels=("Score", "Fgm", "Fgm3", "Ftm", "Or", "Dr", "Ast", "To", "Stl", "Blk", "Pf"), showfliers=False)
plt.title('Statistika pobjednika')
plt.show()

# %%
selected_columns = ["wscore", "wfgm", "wfgm3", "wftm", "wor", "wdr", "wast", "wto", "wstl", "wblk", "wpf"]
selected_data = rsdr[selected_columns]

plt.figure(figsize=(8, 6))
sns.heatmap(selected_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Korelacija statistike pobjednika')
plt.show()

# %% [markdown]
# ##### Gubitnici

# %%
plt.boxplot([rsdr.lscore, rsdr.lfgm, rsdr.lfgm3, rsdr.lftm, rsdr.lor, rsdr.ldr, rsdr["last"], rsdr.lto, rsdr.lstl, rsdr.lblk, rsdr.lpf], 
            labels=["Score", "Fgm", "Fgm3", "Ftm", "Or", "Dr", "Ast", "To", "Stl", "Blk", "Pf"], showfliers=False)
plt.title('Statistika gubitnika')
plt.show()

# %%
selected_columns = ["lscore", "lfgm", "lfgm3", "lftm", "lor", "ldr", "last", "lto", "lstl", "lblk", "lpf"]
selected_data = rsdr[selected_columns]

plt.figure(figsize=(8, 6))
sns.heatmap(selected_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Korelacija statistike gubitnika')
plt.show()

# %% [markdown]
# ##### Razlika pobjednik-gubitnik

# %%
plt.boxplot([rsdr.wscore - rsdr.lscore, rsdr.wfgm - rsdr.lfgm, rsdr.wfgm3 - rsdr.lfgm3, rsdr.wftm - rsdr.lftm, rsdr.wor - rsdr.lor,
            rsdr.wdr - rsdr.ldr, rsdr["wast"] - rsdr["last"], rsdr.wto - rsdr.lto, rsdr.wstl - rsdr.lstl, 
            rsdr.wblk - rsdr.lblk, rsdr.wpf - rsdr.lpf], 
            labels=["Score", "Fgm", "Fgm3", "Ftm", "Or", "Dr", "Ast", "To", "Stl", "Blk", "Pf"], showfliers=False)
plt.title('Razlike statistika pobjednika i gubitnika')
plt.show()

# %%
diff = pd.DataFrame()
diff['score'] = rsdr['wscore'] - rsdr['lscore']
diff['fgm'] = rsdr['wfgm'] - rsdr['lfgm']
diff['fgm3'] = rsdr['wfgm3'] - rsdr['lfgm3']
diff['ftm'] = rsdr['wftm'] - rsdr['lftm']
diff['or'] = rsdr['wor'] - rsdr['lor']
diff['dr'] = rsdr['wdr'] - rsdr['ldr']
diff['ast'] = rsdr['wast'] - rsdr['last']
diff['to'] = rsdr['wto'] - rsdr['lto']
diff['stl'] = rsdr['wstl'] - rsdr['lstl']
diff['blk'] = rsdr['wblk'] - rsdr['lblk']
diff['pf'] = rsdr['wpf'] - rsdr['lpf']

plt.figure(figsize=(8, 6))
sns.heatmap(diff.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Korelacija razlika statistika pobjednika i gubitnika')
plt.show()

# %% [markdown]
# #### Utjecaj numot i wloc na rezultat

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
sns.boxplot(x='numot', y='wscore', data=rsdr, showfliers=False, ax=axes[0])
sns.boxplot(x='numot', y='lscore', data=rsdr, showfliers=False, ax=axes[1])
axes[0].set_title('Pobjednik')
axes[1].set_title('Gubitnik')
axes[0].set_ylabel('Sc')
plt.suptitle('Broj poena o ovisnosti o numot')
plt.show()

# %%
diff['numot'] = rsdr['numot']
sns.boxplot(x='numot', y='score', data=diff, showfliers=False)
plt.title('Razlika pobjednik-gubitnik')
plt.show()

# %%
corr_data = rsdr[['numot', 'wscore', 'lscore']]
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Korelacije poena sa numot')
plt.show()

# %%
corr_data = diff[['numot', 'score']]
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Korelacija razlike poena pobjednika i gubitnika sa numot')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
sns.boxplot(x='wloc', y='wscore', data=rsdr, showfliers=False, ax=axes[0])
sns.boxplot(x='wloc', y='lscore', data=rsdr, showfliers=False, ax=axes[1])
axes[0].set_title('Pobjednik')
axes[1].set_title('Gubitnik')
axes[0].set_ylabel('score')
plt.suptitle('Broj poena o ovisnosti o terenu')
plt.show()

# %% [markdown]
# #### Statistika po sezoni

# %% [markdown]
# Prikazat ćemo podatke o broju poena te one statistike koje imaju veću korelaciju sa brojem poena (Fgm, Ast)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
sns.boxplot(x='season', y='wscore', data=rsdr, showfliers=False, ax=axes[0])
sns.boxplot(x='season', y='lscore', data=rsdr, showfliers=False, ax=axes[1])
axes[0].set_title('Pobjednik')
axes[1].set_title('Gubitnik')
axes[0].set_ylabel('score')
plt.suptitle('Broj poena po sezoni')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
sns.boxplot(x='season', y='wfgm', data=rsdr, showfliers=False, ax=axes[0])
sns.boxplot(x='season', y='wfga', data=rsdr, showfliers=False, ax=axes[1])
axes[0].set_title('Zabijeni koševi')
axes[1].set_title('Bacanja na koš')
axes[0].set_ylabel('broj')
plt.suptitle('Pobjednik')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
sns.boxplot(x='season', y='lfgm', data=rsdr, showfliers=False, ax=axes[0])
sns.boxplot(x='season', y='lfga', data=rsdr, showfliers=False, ax=axes[1])
axes[0].set_title('Zabijeni koševi')
axes[1].set_title('Bacanja na koš')
axes[0].set_ylabel('broj')
plt.suptitle('Gubitnik')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
sns.boxplot(x='season', y='wast', data=rsdr, showfliers=False, ax=axes[0])
sns.boxplot(x='season', y='last', data=rsdr, showfliers=False, ax=axes[1])
axes[0].set_title('Pobjednik')
axes[1].set_title('Gubitnik')
axes[0].set_ylabel('ast')
plt.suptitle('Broj asistencija po sezoni')
plt.show()

# %% [markdown]
# ### Rezultati svake utakmice bez detaljne statistike
# Od sezone 1985. do 2014.

# %%
with pd.option_context("display.max_rows", 10, 'display.max_columns', None):
    display(rscr)
# Out:
#         season  daynum  wteam  wscore  lteam  lscore wloc  numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 134561    2014     132   1196      61   1246      60    N      0
# 134562    2014     132   1277      69   1276      55    N      0
# 134563    2014     132   1386      65   1433      61    N      0
# 134564    2014     132   1418      82   1209      81    N      1
# 134565    2014     132   1438      72   1181      63    N      0
#
# [134566 rows x 8 columns]

# %%
rscr.describe(include='all')
# Out:
#                season         daynum          wteam         wscore  \
# count   134566.000000  134566.000000  134566.000000  134566.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean      2000.465140      75.573748    1286.570404      76.688614
# std          8.680053      33.084248     104.564012      12.253340
# min       1985.000000       0.000000    1101.000000      34.000000
# 25%       1993.000000      47.000000    1197.000000      68.000000
# 50%       2001.000000      78.000000    1283.000000      76.000000
# 75%       2008.000000     103.000000    1379.000000      84.000000
# max       2014.000000     132.000000    1464.000000     186.000000
#
#                 lteam         lscore    wloc          numot
# count   134566.000000  134566.000000  134566  134566.000000
# ...

# %% [markdown]
# #### Nedostajuće vrijednosti

# %%
rscr.isna().sum()
# Out:
# season    0
# daynum    0
# wteam     0
# wscore    0
# lteam     0
# lscore    0
# wloc      0
# numot     0
# dtype: int64

# %% [markdown]
# Možemo vidjeti da ova tablica nema nedostajuće vrijednosti

# %% [markdown]
# ### Rezultati završnog turnira sezone
# Rezulati svake utakmice u završnom turniru sezone sa potpunom statistikom od sezone 2003. do 2014.

# %%
with pd.option_context("display.max_rows", 10, 'display.max_columns', None):
    display(tdr)
# Out:
#      season  daynum  wteam  wscore  lteam  lscore wloc  numot  wfgm  wfga  \
# 0      2003     134   1421      92   1411      84    N      1    32    69
# 1      2003     136   1112      80   1436      51    N      0    31    66
# 2      2003     136   1113      84   1272      71    N      0    31    59
# 3      2003     136   1141      79   1166      73    N      0    29    53
# 4      2003     136   1143      76   1301      74    N      1    27    64
# ..      ...     ...    ...     ...    ...     ...  ...    ...   ...   ...
# 775    2014     146   1163      60   1277      54    N      0    17    49
# 776    2014     146   1246      75   1276      72    N      0    31    58
# 777    2014     152   1163      63   1196      53    N      0    24    43
# 778    2014     152   1246      74   1458      73    N      0    29    58
# 779    2014     154   1163      60   1246      54    N      0    22    53
#
#      wfgm3  wfga3  wftm  wfta  wor  wdr  wast  wto  wstl  wblk  wpf  lfgm  \
# ...

# %% [markdown]
# Značajke su iste kao i u prethodnoj tablici za regularni dio sezone <br>

# %%
tdr.describe(include='all')
# Out:
#              season      daynum        wteam      wscore        lteam  \
# count    780.000000  780.000000   780.000000  780.000000   780.000000
# unique          NaN         NaN          NaN         NaN          NaN
# top             NaN         NaN          NaN         NaN          NaN
# freq            NaN         NaN          NaN         NaN          NaN
# mean    2008.561538  139.087179  1291.653846   74.610256  1294.279487
# std        3.465592    4.220810   102.276919   10.693268   106.652370
# min     2003.000000  134.000000  1104.000000   47.000000  1102.000000
# 25%     2006.000000  136.000000  1210.000000   67.000000  1207.000000
# 50%     2009.000000  137.000000  1277.000000   74.000000  1293.000000
# 75%     2012.000000  139.000000  1393.000000   81.000000  1393.000000
# max     2014.000000  154.000000  1462.000000  121.000000  1462.000000
#
#             lscore wloc       numot        wfgm        wfga  ...       lfga3  \
# ...

# %% [markdown]
# #### Nedostajuće vrijednosti

# %%
tdr.isna().sum()
# Out:
# season    0
# daynum    0
# wteam     0
# wscore    0
# lteam     0
# lscore    0
# wloc      0
# numot     0
# wfgm      0
# wfga      0
# wfgm3     0
# wfga3     0
# wftm      0
# wfta      0
# wor       0
# wdr       0
# wast      0
# wto       0
# wstl      0
# wblk      0
# wpf       0
# lfgm      0
# lfga      0
# lfgm3     0
# lfga3     0
# lftm      0
# lfta      0
# lor       0
# ldr       0
# last      0
# lto       0
# lstl      0
# lblk      0
# lpf       0
# dtype: int64

# %% [markdown]
# Možemo vidjeti da ova tablica nema nedostajuće vrijednosti

# %% [markdown]
# #### Rezultati svake utakmice bez detaljne statistike
# Od sezone 1985. do 2014.

# %%
with pd.option_context("display.max_rows", 10, 'display.max_columns', None):
    display(tcr)
# Out:
#       season  daynum  wteam  wscore  lteam  lscore wloc  numot
# 0       1985     136   1116      63   1234      54    N      0
# 1       1985     136   1120      59   1345      58    N      0
# 2       1985     136   1207      68   1250      43    N      0
# 3       1985     136   1229      58   1425      55    N      0
# 4       1985     136   1242      49   1325      38    N      0
# ...      ...     ...    ...     ...    ...     ...  ...    ...
# 1911    2014     146   1163      60   1277      54    N      0
# 1912    2014     146   1246      75   1276      72    N      0
# 1913    2014     152   1163      63   1196      53    N      0
# 1914    2014     152   1246      74   1458      73    N      0
# 1915    2014     154   1163      60   1246      54    N      0
#
# [1916 rows x 8 columns]

# %%
tcr.describe(include='all')
# Out:
#              season       daynum        wteam       wscore        lteam  \
# count   1916.000000  1916.000000  1916.000000  1916.000000  1916.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean    1999.639875   139.171190  1284.301670    76.983820  1291.354906
# std        8.693250     4.208151   100.211957    12.062641   103.013955
# min     1985.000000   134.000000  1104.000000    43.000000  1102.000000
# 25%     1992.000000   136.000000  1207.000000    69.000000  1208.000000
# 50%     2000.000000   137.000000  1275.500000    76.000000  1285.500000
# 75%     2007.000000   139.000000  1381.250000    84.000000  1387.000000
# max     2014.000000   154.000000  1462.000000   149.000000  1462.000000
#
#              lscore  wloc        numot
# count   1916.000000  1916  1916.000000
# ...

# %% [markdown]
# #### Nedostajuće vrijednosti

# %%
tcr.isna().sum()
# Out:
# season    0
# daynum    0
# wteam     0
# wscore    0
# lteam     0
# lscore    0
# wloc      0
# numot     0
# dtype: int64

# %% [markdown]
# Možemo vidjeti da ova tablica nema nedostajuće vrijednosti

# %% [markdown]
# ### Oznake timova na završnom turniru
# Identifikacija oznaka za 64 tima u svakom zavšnom turniru

# %%
with pd.option_context("display.max_rows", 10, 'display.max_columns', None):
    display(tse)
# Out:
#       season seed  team
# 0       1985  W01  1207
# 1       1985  W02  1210
# 2       1985  W03  1228
# 3       1985  W04  1260
# 4       1985  W05  1374
# ...      ...  ...   ...
# 1941    2014  Z12  1295
# 1942    2014  Z13  1308
# 1943    2014  Z14  1418
# 1944    2014  Z15  1110
# 1945    2014  Z16  1451
#
# [1946 rows x 3 columns]

# %% [markdown]
# Pojašnjenja značajki:
#  - Season &ndash; jedno-znakovni identifikator sezone
#  - Seed &ndash; troznakovni oznaka tima
#  - Team &ndash; Id momčadi

# %%
tse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   season  1946 non-null   int64
#  1   seed    1946 non-null   object
#  2   team    1946 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 45.7+ KB

# %%
tse.describe(include='all')
# Out:
#              season  seed         team
# count   1946.000000  1946  1946.000000
# unique          NaN    86          NaN
# top             NaN   W01          NaN
# freq            NaN    30          NaN
# mean    1999.637718   NaN  1290.664440
# std        8.692685   NaN   102.916408
# min     1985.000000   NaN  1102.000000
# 25%     1992.000000   NaN  1208.000000
# 50%     2000.000000   NaN  1285.000000
# 75%     2007.000000   NaN  1386.000000
# max     2014.000000   NaN  1462.000000

# %% [markdown]
# ### Turnirska uparivanja
# Popis uparivanja utakmica u završnom turniru

# %%
with pd.option_context("display.max_rows", 10, 'display.max_columns', None):
    display(tsl)
# Out:
#       season  slot strongseed weakseed
# 0       1985  R1W1        W01      W16
# 1       1985  R1W2        W02      W15
# 2       1985  R1W3        W03      W14
# 3       1985  R1W4        W04      W13
# 4       1985  R1W5        W05      W12
# ...      ...   ...        ...      ...
# 1911    2014  R6CH       R5WX     R5YZ
# 1912    2014   X16       X16a     X16b
# 1913    2014   Y11       Y11a     Y11b
# 1914    2014   Y12       Y12a     Y12b
# 1915    2014   Y16       Y16a     Y16b
#
# [1916 rows x 4 columns]

# %% [markdown]
# Pojašnjenja značajki:
#  - Season &ndash; jedno-znakovni identifikator sezone
#  - Slot &ndash; identifikator uparivanja timova u završnom turniru po rundama
#  - Strongseed &ndash; oznaka momčadi ili pobjednika prošle runde za koje se smatra da će pobijediti u ovoj rundi
#  - Weakseed &ndash; oznaka momčadi ili pobjednika prošle runde za koje se smatra da će izgubiti u ovoj rundi

# %%
tsl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1916 entries, 0 to 1915
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      1916 non-null   int64
#  1   slot        1916 non-null   object
#  2   strongseed  1916 non-null   object
#  3   weakseed    1916 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 60.0+ KB

# %%
tsl.describe(include='all')
# Out:
#              season  slot strongseed weakseed
# count   1916.000000  1916       1916     1916
# unique          NaN    74         74       74
# top             NaN  R1W1        W01      W16
# freq            NaN    30         30       30
# mean    1999.639875   NaN        NaN      NaN
# std        8.693250   NaN        NaN      NaN
# min     1985.000000   NaN        NaN      NaN
# 25%     1992.000000   NaN        NaN      NaN
# 50%     2000.000000   NaN        NaN      NaN
# 75%     2007.000000   NaN        NaN      NaN
# max     2014.000000   NaN        NaN      NaN
